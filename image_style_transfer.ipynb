# %%
import torchvision.models as models # vgg Models
from imageio import imread # Image Reading
import matplotlib.pyplot as plt
import torchvision.models as models # VGG 19 Model
import torch
from torch.autograd import Variable

# %% [markdown]
# ### Parse Image

# %%
inImg = imread('./images/in0.png');
styImg = imread('./images/style0.png')
fig,axes = plt.subplots(1,2,figsize=(12,5),dpi=150)
axes[0].imshow(inImg)
axes[0].set_title("Input Image")
axes[0].axis("off")

axes[1].imshow(styImg)
axes[1].set_title("Style Image")
axes[1].axis("off")
# Out:
# (-0.5, 699.5, 392.5, -0.5)

# %% [markdown]
# ### Feature Extraction using vgg19

# %%
vgg19 = models.vgg19(pretrained= True) # A pretrained VGG19

# %%
torch.T
